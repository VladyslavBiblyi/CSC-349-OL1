# %% [markdown]
# <a href="https://colab.research.google.com/github/VladyslavBiblyi/CSC-349-OL1/blob/main/HW2/Analysis_(Questions).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis (Questions)

# %% [markdown]
# #1.
# I couldnt load the dataset directly from my PC into Colab, so I had to upload it to GitHub and loaded it using a raw GitHub link(i just copied it from one your examples). This was a little bit more confusing than loading it directly.
#
# #2.
# I used isnull().sum() to find missing values. encryption_used had 1,966 missing values, so I replaced them with the most frequent value. Numerical missing values I replaced with the median. I dropped session_id because it was only an identifier.
#
# #3.
# The ColumnTransformer applies the correct preparation method to each column type. The pipelines combines imputation, scaling, and encoding into one process. This makes the code much shorter and makes sure that the same steps are applied all the time. To prevent data leakage during model training, the pipeline should be applied only on the training data and then applied to the test data.
#
# #4.
# The strongest relationships with attack_detected were failed_logins (0.36), login_attempts (0.28), and ip_reputation_score (0.21). This shows that repeated failed logins, many login attempts, and suspicious IP scores are useful warning signs of an attack.
